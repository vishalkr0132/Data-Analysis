# %%
import numpy as np
import pandas as pd

# %%
dataset = {
    'name':['vishal','Baba','veera','deviya','tushar'],
    'age':[22,23,24,20,18],
    'city':['BH','AP','AP','TN','BH']
}
df = pd.DataFrame(dataset)
df
# Out:
#      name  age city
# 0  vishal   22   BH
# 1    Baba   23   AP
# 2   veera   24   AP
# 3  deviya   20   TN
# 4  tushar   18   BH

# %%
num = df.shape
rows, columns = num
print(rows,columns, sep = '\n')
# Out:
# 5
# 3

# %%
df.head(3)
# Out:
#      name  age city
# 0  vishal   22   BH
# 1    Baba   23   AP
# 2   veera   24   AP

# %%
df.head(-2)
# Out:
#      name  age city
# 0  vishal   22   BH
# 1    Baba   23   AP
# 2   veera   24   AP

# %%
df[df['name'] == 'vishal']
# Out:
#      name  age city
# 0  vishal   22   BH

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   age     5 non-null      int64
#  2   city    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 248.0+ bytes

# %%
df.describe(include=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.describe(include=True)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py:10940, in NDFrame.describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10691 @final
#   10692 def describe(
#   10693     self: NDFrameT,
#    (...)
#   10697     datetime_is_numeric: bool_t = False,
#   10698 ) -> NDFrameT:
#   10699     """
#   10700     Generate descriptive statistics.
#   10701
#    (...)
#   10938     max            NaN      3.0
#   10939     """
# > 10940     return describe_ndframe(
#   10941         obj=self,
#   10942         include=include,
#   10943         exclude=exclude,
#   10944         datetime_is_numeric=datetime_is_numeric,
#   10945         percentiles=percentiles,
#   10946     )
#
# ...

# %%
df['sal']=[5000,2000,3000,4000,2000]

# %%
df
# Out:
#      name  age city   sal
# 0  vishal   22   BH  5000
# 1    Baba   23   AP  2000
# 2   veera   24   AP  3000
# 3  deviya   20   TN  4000
# 4  tushar   18   BH  2000

# %%
df.reset_index(inplace=True)
df
# Out:
#    level_0  index    name  age city   sal
# 0        0      0  vishal   22   BH  5000
# 1        1      1    Baba   23   AP  2000
# 2        2      2   veera   24   AP  3000
# 3        3      3  deviya   20   TN  4000
# 4        4      4  tushar   18   BH  2000

# %%
df.set_index('name',inplace=True)

# %%
df
# Out:
#         level_0  index  age city   sal
# name
# vishal        0      0   22   BH  5000
# Baba          1      1   23   AP  2000
# veera         2      2   24   AP  3000
# deviya        3      3   20   TN  4000
# tushar        4      4   18   BH  2000

# %%
df[df['age'] > 20]
df
# Out:
#         level_0  index  age city   sal
# name
# vishal        0      0   22   BH  5000
# Baba          1      1   23   AP  2000
# veera         2      2   24   AP  3000
# deviya        3      3   20   TN  4000
# tushar        4      4   18   BH  2000

# %%
dataset = {
    'name':['vishal','Baba','veera','deviya','tushar'],
    'age':[22,23,24,20,18],
    'city':['BH','AP','AP','TN','BH']
}
df = pd.DataFrame(dataset)
df
# Out:
#      name  age city
# 0  vishal   22   BH
# 1    Baba   23   AP
# 2   veera   24   AP
# 3  deviya   20   TN
# 4  tushar   18   BH

# %%
df.to_csv('dataset.csv')

# %%
df=pd.read_csv('dataset.csv')
df
# Out:
#    Unnamed: 0    name  age city
# 0           0  vishal   22   BH
# 1           1    Baba   23   AP
# 2           2   veera   24   AP
# 3           3  deviya   20   TN
# 4           4  tushar   18   BH

# %%
df.to_excel('dataset.xlsx')

# %%
df=pd.read_excel('dataset.xlsx')
df
# Out:
#    Unnamed: 0.1  Unnamed: 0    name  age city
# 0             0           0  vishal   22   BH
# 1             1           1    Baba   23   AP
# 2             2           2   veera   24   AP
# 3             3           3  deviya   20   TN
# 4             4           4  tushar   18   BH

# %%
df.to_json('dataset.json')

# %%
dataset1 = {
    'name':['vishal','Baba','veera','deviya','tushar'],
    'age':[22,23,24,20,18],
    'city':['BH','AP','AP','TN','BH']
}
df1 = pd.DataFrame(dataset)
df1
# Out:
#      name  age city
# 0  vishal   22   BH
# 1    Baba   23   AP
# 2   veera   24   AP
# 3  deviya   20   TN
# 4  tushar   18   BH

# %%
dataset2 = {
    'name':['vishal1','Baba1','veera1','deviya1','tushar1'],
    'age':[22,23,24,20,19],
    'city':['BH','AP','AP','TN','BH']
}
df2 = pd.DataFrame(dataset)
df2
# Out:
#      name  age city
# 0  vishal   22   BH
# 1    Baba   23   AP
# 2   veera   24   AP
# 3  deviya   20   TN
# 4  tushar   18   BH

# %%
df = pd.concat([df1, df2],axis=1)

# %%
df
# Out:
#      name  age city
# 0  vishal   22   BH
# 1    Baba   23   AP
# 2   veera   24   AP
# 3  deviya   20   TN
# 4  tushar   18   BH
# 0  vishal   22   BH
# 1    Baba   23   AP
# 2   veera   24   AP
# 3  deviya   20   TN
# 4  tushar   18   BH
